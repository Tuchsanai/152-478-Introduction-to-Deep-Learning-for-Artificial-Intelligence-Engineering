# %% [markdown]
# ## Example API: Eurostat
#
# Let's dive in by looking at an API that can be of use to us, the [EUROSTAT API](https://ec.europa.eu/eurostat/web/json-and-unicode-web-services).
#
# The documentation linked gives a very useful summary of the structure of the requests:
# ![](https://github.com/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/APIs/figures/eurostat_api.png?raw=1)
#
# * host_url : fixed part of the request related to our website
# * service : fixed part of the request related to the service
# * version : fixed part of the request related to the version of the service
# * format : data format to be returned (json or unicode)
# * lang : language used for metadata (en/fr/de)
# * datasetCode : unique code identifier of the queried dataset
# * filters : specify the scope of the query (optional). There is a threshold of maximum 50 sub-indicators per query. The filters are specific to a dataset, depending on dataset dimensions.
#     * precision : the number of decimals for the values returned by the request
#     * unit : filter on the dataset's UNIT dimension

# %% [markdown]
# # ตัวอย่าง 0 . การค้นหาใน Google
#
# https://www.google.com/search?q=cat
#
# ![](./image/0.png)

# %% [markdown]
# # ตัวอย่าง 1. การหาตารางสอนของ  officerid=20710
#
# https://home.sis.siam.edu/registrar/teach_time.asp?officerid=20710
#
# ![](https://raw.githubusercontent.com/Tuchsanai/152-495-Special-Topics-in-Electrical-Engineering/4e2a8ebb5a2354c54f59219ab616171aadbd5869/03_3_Api%20and%20Web%20scraping/image/1.png)

# %% [markdown]
# # ตัวอย่าง 2.การหารายชื่อ อาจารย์ทั้งหมด
# https://home.sis.siam.edu/registrar/teach_time.asp?f_cmd=1
#
# ![](https://raw.githubusercontent.com/Tuchsanai/152-495-Special-Topics-in-Electrical-Engineering/4e2a8ebb5a2354c54f59219ab616171aadbd5869/03_3_Api%20and%20Web%20scraping/image/2.png)

# %% [markdown]
# # Basic HTML Document
#
# ![](https://raw.githubusercontent.com/Tuchsanai/152-495-Special-Topics-in-Electrical-Engineering/4e2a8ebb5a2354c54f59219ab616171aadbd5869/03_3_Api%20and%20Web%20scraping/image/3.png)
#
# ![](https://raw.githubusercontent.com/Tuchsanai/152-495-Special-Topics-in-Electrical-Engineering/4e2a8ebb5a2354c54f59219ab616171aadbd5869/03_3_Api%20and%20Web%20scraping/image/4.png)
#
# ![](https://raw.githubusercontent.com/Tuchsanai/152-495-Special-Topics-in-Electrical-Engineering/4e2a8ebb5a2354c54f59219ab616171aadbd5869/03_3_Api%20and%20Web%20scraping/image/5.png)

# %% [markdown]
# # Beginning to scrape with BeautifulSoup

# %%
# Install beautifulsoup4
# !pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.10.0 soupsieve-2.2.1

# %%
from bs4 import BeautifulSoup
import requests

# %%
html = requests.get("https://keithgalli.github.io/web-scraping/example.html")
bs = BeautifulSoup(html.content, "html.parser")
print(bs.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    HTML Example
#   </title>
#  </head>
#  <body>
#   <div align="middle">
#    <h1>
#     HTML Webpage
#    </h1>
#    <p>
#     Link to more interesting example:
#     <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#      keithgalli.github.io/web-scraping/webpage.html
#     </a>
#    </p>
#   </div>
#   <h2>
#    A Header
#   </h2>
#   <p>
#    <i>
#     Some italicized text
#    </i>
#   </p>
#   <h2>
#    Another header
#   </h2>
#   <p id="paragraph-id">
#    <b>
#     Some bold text
#    </b>
#   </p>
#  </body>
# </html>

# %% [markdown]
# ## find() and find_all() with BeautifulSoup

# %%
result_find = bs.find('h2')
result_findall = bs.find_all('h2')

print('find: ', result_find)
print('find_all: ', result_findall)
# Out:
# find:  <h2>A Header</h2>
# find_all:  [<h2>A Header</h2>, <h2>Another header</h2>]

# %%
result_header_tags = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('Header: ', result_header_tags)

result_p_tags = bs.find_all('p')
print('p: ', result_p_tags)
# Out:
# Header:  [<h1>HTML Webpage</h1>, <h2>A Header</h2>, <h2>Another header</h2>]
# p:  [<p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>, <p><i>Some italicized text</i></p>, <p id="paragraph-id"><b>Some bold text</b></p>]

# %%
for tag in result_p_tags:
    print(tag.get_text())
# Out:
# Link to more interesting example: keithgalli.github.io/web-scraping/webpage.html
# Some italicized text
# Some bold text

# %%
result_p_by_id = bs.find('p', attrs={'id': 'paragraph-id'})
print(result_p_by_id.get_text())
# Out:
# Some bold text

# %% [markdown]
# # โจทย์ 1. จงหารายชื่อ อาจารย์ ม. สยาม จาก
#
# https://home.sis.siam.edu/registrar/teach_time.asp?f_cmd=1
#
# Hint :

# %% [raw]
# <td>&nbsp;<font face="MS Sans Serif" size="3">ฉัตรสุมน พฤฒิภิญโญ</font></td>

# %% [raw]
# <tr><td width="20"></td><td align="RIGHT">12</td>
# <td width="10"></td><td><a href="teach_time.asp?officerid=10151&amp;f_cmd=2&amp;officercode=00076&amp;officername=%CD%D2%A8%D2%C3%C2%EC+%B3%D1%B0%B9%D1%B9%B7%EC+%BB%C3%D0%A1%D2%C2%CA%D1%B9%B5%D4%CA%D8%A2&amp;remark=%CD%D2%A4%D2%C3+15+%AA%D1%E9%B9+4&amp;officeremail="><font face="MS Sans Serif" size="3">อาจารย์ ณัฐนันท์ ประกายสันติสุข</font></a></td><td>&nbsp;<font face="MS Sans Serif" size="3">
# Nattanan Prakaisantisuk</font></td></tr>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

html = requests.get("https://home.sis.siam.edu/registrar/teach_time.asp?f_cmd=1")
bs = BeautifulSoup(html.content, "html.parser")

# %% [markdown]
# วิธีที่ 1

# %%
result_findall = bs.find_all(['td'])

L_name = []

for tag_td in result_findall :
     font_tag = tag_td.find('font',attrs={"face":"MS Sans Serif" ,'size':'3'})
     if font_tag :
        L_name.append(font_tag.get_text())
    
    
df= pd.DataFrame({'name':L_name})
df
# Out:
#                                                name
# 0                                  ดร. ไกร โพธิ์งาม
# 1                                  ดร. ไกร โพธิ์งาม
# 2                                      ไกร โพธิ์งาม
# 3                             ดร. ไพรัช วงศ์ยุทธไกร
# 4                                 ไพรัช วงศ์ยุทธไกร
# ...                                             ...
# 5080                                SEREE WONGMONTA
# 5081                       อาจารย์ ชารีฟ เด่นสุมิตร
# 5082                               SHARIF DENSUMITE
# 5083  อาจารย์ ภาควิชาเทคโนโลยีดิจิทัลและนวัตกรรม_1
# 5084          ภาควิชาเทคโนโลยีดิจิทัลและนวัตกรรม_1
#
# [5085 rows x 1 columns]

# %%
# dropping ALL duplicate values
df = df.drop_duplicates(subset ="name",keep = False)
df = df.reset_index(drop=True)
df
# Out:
#                                                name
# 0                                      ไกร โพธิ์งาม
# 1                             ดร. ไพรัช วงศ์ยุทธไกร
# 2                                 ไพรัช วงศ์ยุทธไกร
# 3                          อาจารย์ กาญจนี มนต์วิเศษ
# 4                                  กาญจนี มนต์วิเศษ
# ...                                             ...
# 4901                                SEREE WONGMONTA
# 4902                       อาจารย์ ชารีฟ เด่นสุมิตร
# 4903                               SHARIF DENSUMITE
# 4904  อาจารย์ ภาควิชาเทคโนโลยีดิจิทัลและนวัตกรรม_1
# 4905          ภาควิชาเทคโนโลยีดิจิทัลและนวัตกรรม_1
#
# [4906 rows x 1 columns]

# %% [markdown]
# วิธี 2.

# %%
result_findall = bs.find_all(['tr'])

L_name = []
L_url = []


for tag_tr in result_findall :
    
   tag_a    = tag_tr.find('a', href=True)
   font_tag = tag_tr.find_all(['font'],attrs={"face":"MS Sans Serif" ,'size':'3'})
    

   if  tag_a and len(font_tag)==2:
        url   = 'https://home.sis.siam.edu/registrar/'+tag_a['href']
        name  = font_tag[0].get_text()
        L_url.append(url)
        L_name.append(name)
        
        
    
df = pd.DataFrame({'name':L_name, 'url':L_url})
df = df.drop_duplicates(subset ="name",keep = False)
df = df.reset_index(drop=True)

df
# Out:
#                                                name  \
# 0                                  ดร. ไกร โพธิ์งาม
# 1                             ดร. ไพรัช วงศ์ยุทธไกร
# 2                          อาจารย์ กาญจนี มนต์วิเศษ
# 3                          อาจารย์ ขนิษฐา สังขรัตน์
# 4                            อาจารย์ คนึง ม่วงกล่อม
# ...                                             ...
# 2529                            ดร. รัฐศาสตร์ กรสูต
# 2530          รองศาสตราจารย์ นพ. พรพรต ลิ้มประเสริฐ
# 2531                              ดร. เสรี วงษ์มณฑา
# 2532                       อาจารย์ ชารีฟ เด่นสุมิตร
# 2533  อาจารย์ ภาควิชาเทคโนโลยีดิจิทัลและนวัตกรรม_1
#
#                                                     url
# 0     https://home.sis.siam.edu/registrar/teach_time...
# 1     https://home.sis.siam.edu/registrar/teach_time...
# 2     https://home.sis.siam.edu/registrar/teach_time...
# 3     https://home.sis.siam.edu/registrar/teach_time...
# 4     https://home.sis.siam.edu/registrar/teach_time...
# ...                                                 ...
# 2529  https://home.sis.siam.edu/registrar/teach_time...
# 2530  https://home.sis.siam.edu/registrar/teach_time...
# 2531  https://home.sis.siam.edu/registrar/teach_time...
# 2532  https://home.sis.siam.edu/registrar/teach_time...
# 2533  https://home.sis.siam.edu/registrar/teach_time...
#
# [2534 rows x 2 columns]

# %%
i = 50
df.loc[i]['name']
# Out:
# 'อาจารย์ สุรชาติ ศรีเมืองใต้'

# %%
df.loc[i]['url']
# Out:
# 'https://home.sis.siam.edu/registrar/teach_time.asp?officerid=10479&f_cmd=2&officercode=39123013&officername=%CD%D2%A8%D2%C3%C2%EC+%CA%D8%C3%AA%D2%B5%D4+%C8%C3%D5%E0%C1%D7%CD%A7%E3%B5%E9&remark=&officeremail='

# %% [markdown]
# ### ปัจจุบัน มี 3 เว็บที่แสดงข้อมูลคุณภาพอากาศปัจจุบันในประเทศไทยที่ใช้ข้อมูลจากสถานีวัดอากาศที่ไม่ใช้ข้อมูลจากดาวเทียมดังนี้
# - AIR4THAI - เป็นข้อมูลจากกองจัดการคุณภาพอากาศและเสียง กรมควบคุมมลพิษ ที่ให้บริการบนเว็บ air4thai.pcd.go.th
# - Bangkok Air Quality - เป็นข้อมูลจากกองจัดการคุณภาพอากาศและเสียงกรุงเทพมหานคร ที่ให้บริการคุณภาพอากาศตามจุดต่าง ๆ ของกรุงเทพมหานคร บนเว็บ bangkokairquality.com
# - ศูนย์เฝ้าระวังคุณภาพอากาศ วช. - เป็นข้อมูลที่ทางสำนักงานการวิจัยแห่งชาติ (วช.) รวบรวมมาจัดทำเป็นเว็บให้บริการตรวจสอบคุณภาพอากาศประเทศไทยได้ทั่วโลก โดยให้บริการบนเว็บ pm2_5.nrct.go.th
#
# ### ทั้งสามเว็บปรับปรุงข้อมูลทุก ๆ  1 ชั่วโมง โดยมีเพียง AIR4THAI เท่านั้นที่มี API ทั้ง JSON และ XML ให้ดึงไปใช้งานได้

# %%
import requests

url = 'http://air4thai.pcd.go.th/services/getNewAQI_JSON.php'
output = requests.get(url).json()
output
# Out:
# {'stations': [{'stationID': '02t',
#    'nameTH': 'มหาวิทยาลัยราชภัฏบ้านสมเด็จเจ้าพระยา',
#    'nameEN': 'Bansomdejchaopraya Rajabhat University',
#    'areaTH': 'แขวงหิรัญรูจี เขตธนบุรี, กรุงเทพฯ',
#    'areaEN': 'Hiran Ruchi, Khet Thon Buri, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.732846',
#    'long': '100.487662',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '17:00',
#     'PM25': {'value': '11', 'unit': 'µg/m³'},
#     'PM10': {'value': '20', 'unit': 'µg/m³'},
#     'O3': {'value': '16', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '5', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '11'}}},
#   {'stationID': '03t',
#    'nameTH': 'ริมถนนทางหลวงหมายเลข 3902 ',
#    'nameEN': 'Highway NO.3902 km.13 +600',
#    'areaTH': 'ริมถนนกาญจนาภิเษก เขตบางขุนเทียน, กรุงเทพฯ',
#    'areaEN': 'Kanchanaphisek Rd, Bang Khun Thian, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.636514',
#    'long': '100.414262',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '12:00',
#     'PM25': {'value': '17', 'unit': 'µg/m³'},
#     'PM10': {'value': '45', 'unit': 'µg/m³'},
#     'O3': {'value': '5', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '23'}}},
#   {'stationID': '05t',
#    'nameTH': 'กรมอุตุนิยมวิทยาบางนา',
#    'nameEN': 'Thai Meteorological Department ',
#    'areaTH': 'แขวงบางนา เขตบางนา, กรุงเทพฯ',
#    'areaEN': 'Bang Na, Khet Bang Na, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.666183',
#    'long': '100.605742',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '5', 'unit': 'µg/m³'},
#     'PM10': {'value': '11', 'unit': 'µg/m³'},
#     'O3': {'value': '26', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '19'}}},
#   {'stationID': '10t',
#    'nameTH': 'เคหะชุมชนคลองจั่น',
#    'nameEN': 'National Housing Authority Klongchan',
#    'areaTH': 'แขวงคลองจั่น เขตบางกะปิ, กรุงเทพฯ',
#    'areaEN': 'Khlong Chan, Khet Bang Kapi, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.779873',
#    'long': '100.646009',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '5', 'unit': 'µg/m³'},
#     'PM10': {'value': '15', 'unit': 'µg/m³'},
#     'O3': {'value': '21', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '15'}}},
#   {'stationID': '11t',
#    'nameTH': 'การเคหะชุมชนห้วยขวาง ',
#    'nameEN': 'National Housing  Huaykwang',
#    'areaTH': 'แขวงดินแดง เขตดินแดง, กรุงเทพฯ',
#    'areaEN': 'Din Daeng, Khet Din Daeng, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.77553',
#    'long': '100.569195',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '17:00',
#     'PM25': {'value': '7', 'unit': 'µg/m³'},
#     'PM10': {'value': '16', 'unit': 'µg/m³'},
#     'O3': {'value': '17', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '12'}}},
#   {'stationID': '12t',
#    'nameTH': 'โรงเรียนนนทรีวิทยา ',
#    'nameEN': 'Nonsi Witthaya School',
#    'areaTH': 'แขวงช่องนนทรี เขตยานนาวา, กรุงเทพฯ',
#    'areaEN': 'Chong Nonsi, Khet Yannawa, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.708067',
#    'long': '100.547333',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '17:00',
#     'PM25': {'value': '6', 'unit': 'µg/m³'},
#     'PM10': {'value': '17', 'unit': 'µg/m³'},
#     'O3': {'value': '-', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '16', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '9'}}},
#   {'stationID': '50t',
#    'nameTH': 'โรงพยาบาลจุฬาลงกรณ์',
#    'nameEN': 'Chulalongkorn Hospital',
#    'areaTH': 'ริมถนนพระราม 4 เขตปทุมวัน, กรุงเทพฯ',
#    'areaEN': 'Rama IV Rd. Khet Pathum Wan, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.729852',
#    'long': '100.536501',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': '21', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '11'}}},
#   {'stationID': '52t',
#    'nameTH': 'การไฟฟ้าย่อยธนบุรี ',
#    'nameEN': 'Thonburi Power Sub-Station',
#    'areaTH': 'ริมถนนอินทรพิทักษ์ เขตธนบุรี, กรุงเทพฯ',
#    'areaEN': 'Intarapitak Rd. Khet Thon Buri, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.727622',
#    'long': '100.486568',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': '19', 'unit': 'µg/m³'},
#     'O3': {'value': '13', 'unit': 'ppb'},
#     'CO': {'value': '0.71', 'unit': 'ppm'},
#     'NO2': {'value': '18', 'unit': 'ppb'},
#     'SO2': {'value': '0', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '10'}}},
#   {'stationID': '53t',
#    'nameTH': 'สถานีตำรวจนครบาลโชคชัย ',
#    'nameEN': 'Chokchai Police Station',
#    'areaTH': 'ริมถนนลาดพร้าว เขตวังทองหลาง, กรุงเทพฯ',
#    'areaEN': 'Lat Phrao Rd. Khet Wang Thonglang, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.795425',
#    'long': '100.593023',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '11', 'unit': 'µg/m³'},
#     'PM10': {'value': '22', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '11'}}},
#   {'stationID': '54t',
#    'nameTH': 'การเคหะชุมชนดินแดง ',
#    'nameEN': 'National Housing Authority Dindaeng',
#    'areaTH': 'ริมถนนดินแดง เขตดินแดง, กรุงเทพฯ',
#    'areaEN': 'Din Daeng Rd. Khet Din Daeng, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.762517',
#    'long': '100.5502',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '18', 'unit': 'µg/m³'},
#     'PM10': {'value': '38', 'unit': 'µg/m³'},
#     'O3': {'value': '9', 'unit': 'ppb'},
#     'CO': {'value': '1.29', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '19'}}},
#   {'stationID': '59t',
#    'nameTH': 'กรมประชาสัมพันธ์',
#    'nameEN': 'The Government Public Relations Department ',
#    'areaTH': 'แขวงพญาไท เขตพญาไท, กรุงเทพฯ',
#    'areaEN': 'Phaya Thai, Khet Phaya Thai, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.783185',
#    'long': '100.540489',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '6', 'unit': 'µg/m³'},
#     'PM10': {'value': '16', 'unit': 'µg/m³'},
#     'O3': {'value': '19', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '21', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '14'}}},
#   {'stationID': '61t',
#    'nameTH': 'โรงเรียนบดินทรเดชา (สิงห์ สิงหเสนี) ',
#    'nameEN': 'Bodindecha Sing Singhaseni School',
#    'areaTH': 'แขวงพลับพลา เขตวังทองหลาง, กรุงเทพฯ',
#    'areaEN': 'Pubpla, Khet Wang Thonglang, Bangkok',
#    'stationType': 'GROUND',
#    'lat': '13.769634',
#    'long': '100.614567',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '17:00',
#     'PM25': {'value': '11', 'unit': 'µg/m³'},
#     'PM10': {'value': '20', 'unit': 'µg/m³'},
#     'O3': {'value': '16', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '11'}}},
#   {'stationID': 'bkp100t',
#    'nameTH': 'สำนักงานเขตบึงกุ่ม',
#    'nameEN': 'Bueng Kum District Office, Bangkok',
#    'areaTH': 'แขวงคลองกุ่ม เขตบึงกุ่ม',
#    'areaEN': 'Khlong Kum, Bueng Kum, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.785212',
#    'long': '100.669183',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '9', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '9'}}},
#   {'stationID': 'bkp101t',
#    'nameTH': 'สำนักงานเขตคลองสามวา',
#    'nameEN': 'Khlong Sam Wa District Office, Bangkok',
#    'areaTH': 'เขตคลองสามวา, กรุงเทพฯ',
#    'areaEN': 'Khlong Sam Wa, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.859911',
#    'long': '100.704002',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '13', 'unit': 'µg/m³'},
#     'PM10': {'value': '16', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '13'}}},
#   {'stationID': 'bkp102t',
#    'nameTH': 'สำนักงานเขตจอมทอง',
#    'nameEN': 'Chomthong District Office, Bangkok',
#    'areaTH': 'เขตจอมทอง, กรุงเทพฯ',
#    'areaEN': 'Chomthong, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.677757',
#    'long': '100.483861',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '6', 'unit': 'µg/m³'},
#     'PM10': {'value': '10', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '6'}}},
#   {'stationID': 'bkp103t',
#    'nameTH': 'สำนักงานเขตบางพลัด',
#    'nameEN': 'Bang Phlat District Office, Bangkok',
#    'areaTH': 'ริมถนนจรัญสนิทวงศ์ เขตบางพลัด, กรุงเทพฯ',
#    'areaEN': 'Charansanitwong Roadside, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.793965',
#    'long': '100.504956',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '4', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '4'}}},
#   {'stationID': 'bkp104t',
#    'nameTH': 'สำนักงานเขตบางแค',
#    'nameEN': 'Bang Khae District Office, Bangkok',
#    'areaTH': 'เขตบางแค, กรุงเทพฯ',
#    'areaEN': 'Bang Khae, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.696314',
#    'long': '100.409049',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '7', 'unit': 'µg/m³'},
#     'PM10': {'value': '8', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '7'}}},
#   {'stationID': 'bkp105t',
#    'nameTH': 'สำนักงานเขตบางขุนเทียน',
#    'nameEN': 'Bang Khun Thian District Office, Bangkok',
#    'areaTH': 'ริมถนนพระราม 2 เขตบางขุนเทียน, กรุงเทพฯ',
#    'areaEN': 'RamaII Roadside,  Bang Khun Thian, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.659908',
#    'long': '100.435902',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '10'}}},
#   {'stationID': 'bkp56t',
#    'nameTH': 'สำนักงานเขตดินแดง กรุงเทพฯ',
#    'nameEN': 'Din Dang, Bangkok',
#    'areaTH': 'ริมถนนวิภาวดีรังสิต, เขตดินแดง, กรุงเทพฯ',
#    'areaEN': 'Din Dang, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.7619223',
#    'long': '100.558606',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '11', 'unit': 'µg/m³'},
#     'PM10': {'value': '36', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '18'}}},
#   {'stationID': 'bkp57t',
#    'nameTH': 'สำนักงานเขตพระโขนง กรุงเทพฯ',
#    'nameEN': 'Phra Kanong District Office,  Bangkok',
#    'areaTH': 'ริมถนนสุขุมวิท เขตพระโขนง, กรุงเทพฯ',
#    'areaEN': 'Phra Kanong, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.691511',
#    'long': '100.61457',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '12', 'unit': 'µg/m³'},
#     'PM10': {'value': '34', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '17'}}},
#   {'stationID': 'bkp58t',
#    'nameTH': 'สำนักงานเขตราษฎร์บูรณะ กรุงเทพฯ',
#    'nameEN': 'Rat Burana District Office,  Bangkok',
#    'areaTH': 'ริมถนนราษฎร์บูรณะ, เขตราษฎร์บูรณะ, กรุงเทพฯ',
#    'areaEN': 'Rat Burana, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.6821364',
#    'long': '100.5060513',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '-', 'unit': 'µg/m³'},
#     'PM10': {'value': '35', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '18'}}},
#   {'stationID': 'bkp59t',
#    'nameTH': 'สำนักงานเขตราชเทวี กรุงเทพฯ',
#    'nameEN': 'Ratchathewi District Office, Bangkok',
#    'areaTH': 'ริมถนนพญาไท เขตราชเทวี, กรุงเทพฯ',
#    'areaEN': 'Phayathai Roadside, Ratchathewi, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.7590851',
#    'long': '100.5345788',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': '17', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '10'}}},
#   {'stationID': 'bkp60t',
#    'nameTH': 'ริมสวนหย่อมตรงข้ามสำนักงานเขตดุสิต',
#    'nameEN': 'Dusit District Office, Bangkok',
#    'areaTH': 'ริมถนนพระราม 5 เขตดุสิต, กรุงเทพฯ',
#    'areaEN': 'RamaV Roadside, Dusit, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.776664',
#    'long': '100.520982',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': '31', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '16'}}},
#   {'stationID': 'bkp61t',
#    'nameTH': 'สำนักงานคณะกรรมการพัฒนาเศรษฐกิจและสังคมแห่งชาติ',
#    'nameEN': 'National Economic and Social Development Council Office',
#    'areaTH': 'ริมถนนกรุงเกษม เขตป้อมปราบศัตรูพ่าย, กรุงเทพฯ',
#    'areaEN': 'Krung Kasem Roadside, Pom Prap Sattru Phai, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.756281',
#    'long': '100.514267',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '15', 'unit': 'µg/m³'},
#     'PM10': {'value': '21', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '15'}}},
#   {'stationID': 'bkp62t',
#    'nameTH': 'วงเวียนโอเดียน',
#    'nameEN': 'Odeon Circus',
#    'areaTH': 'ริมถนนตรีมิตร วงเวียนโอเดียน์ เขตสัมพันธวงศ์, กรุงเทพฯ',
#    'areaEN': 'TheeMitr Roadside, Samphanthawong, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.737136',
#    'long': '100.512734',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '9', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '9'}}},
#   {'stationID': 'bkp63t',
#    'nameTH': 'แฟลตทหารบก สามเสน',
#    'nameEN': 'Army Apartment Sam Sen',
#    'areaTH': 'ริมถนนพระราม 6 เขตพญาไท, กรุงเทพฯ',
#    'areaEN': 'RamaVI Roadside, Phaya Thai, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.783554',
#    'long': '100.5344645',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '8', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '8'}}},
#   {'stationID': 'bkp64t',
#    'nameTH': 'สำนักงานเขตวังทองหลาง',
#    'nameEN': 'Wang Thonglang District Office, Bangkok',
#    'areaTH': 'ริมถนนลาดพร้าว ซอยลาดพร้าว 95 เขตวังทองหลาง, กรุงเทพฯ',
#    'areaEN': 'Lat Phrao Rd Soi 95, Wang Thonglang, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.778981',
#    'long': '100.622294',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '17', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '17'}}},
#   {'stationID': 'bkp65t',
#    'nameTH': 'สามย่านมิตรทาวน์',
#    'nameEN': 'Samyan Mitrtown',
#    'areaTH': 'ริมถนนพระรามที่ 4 หน้าสามย่านมิตรทาวน์ เขตปทุมวัน, กรุงเทพฯ',
#    'areaEN': 'RamaIV Roadside, Pathum Wan, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.733136',
#    'long': '100.52829',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '11', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '11'}}},
#   {'stationID': 'bkp66t',
#    'nameTH': 'ลานบางรักเลิฟลี่ พลาซ่า',
#    'nameEN': 'Bangrak Lovely Plaza',
#    'areaTH': 'ริมถนนนราธิวาส เขตบางรัก, กรุงเทพฯ',
#    'areaEN': 'Narathiwat Roadside, Bang Rak, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.726136',
#    'long': '100.528055',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '9', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '9'}}},
#   {'stationID': 'bkp67t',
#    'nameTH': 'สำนักงานเขตสาทร',
#    'nameEN': 'Sathon District Office, Bangkok',
#    'areaTH': 'แขวงทุ่งวัดดอน เขตสาทร, กรุงเทพฯ',
#    'areaEN': 'Thung Wat Don, Sathon, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.707763',
#    'long': '100.526787',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '13', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '13'}}},
#   {'stationID': 'bkp68t',
#    'nameTH': 'สี่แยกถนนตก',
#    'nameEN': 'Thanon Tok Intersection',
#    'areaTH': 'ริมถนนพระราม 3-เจริญกรุง เขตบางคอแหลม, กรุงเทพฯ',
#    'areaEN': 'RamaIII Roadside (Chareon Krung), Bang Kho Laem, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.697252',
#    'long': '100.497185',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '5', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '5'}}},
#   {'stationID': 'bkp69t',
#    'nameTH': 'ธนาคารกรุงศรีอยุธยา สำนักงานใหญ่',
#    'nameEN': 'Bank of Ayuthaya Head Office Yan Nawa, Bangkok',
#    'areaTH': 'ริมถนนพระราม 3 เขตยานนาวา, กรุงเทพฯ',
#    'areaEN': 'RamaIII Roadside, Yan Nawa, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.679226',
#    'long': '100.54687',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '14', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '14'}}},
#   {'stationID': 'bkp70t',
#    'nameTH': 'ริมถนนซอยสุขุมวิท 63',
#    'nameEN': 'Soi Sukhumwit 63 Roadside Wattana, Bangkok',
#    'areaTH': 'ริมถนนซอยสุขุมวิท 63 เขตวัฒนา, กรุงเทพฯ',
#    'areaEN': 'Soi Sukhumwit 63 Roadside, Wattana, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.722096',
#    'long': '100.584559',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '11', 'unit': 'µg/m³'},
#     'PM10': {'value': '21', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '11'}}},
#   {'stationID': 'bkp71t',
#    'nameTH': 'สำนักงานเขตสวนหลวง',
#    'nameEN': 'Suan Luang District Office, Bangkok',
#    'areaTH': 'ริมถนนพัฒนาการ เขตสวนหลวง, กรุงเทพฯ',
#    'areaEN': 'Suan Luang, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.731051',
#    'long': '100.651705',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': '21', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '11'}}},
#   {'stationID': 'bkp72t',
#    'nameTH': 'บิ๊กซี ซุปเปอร์เซ็นเตอร์ บางนา',
#    'nameEN': 'Big C Supercenter Bang Na',
#    'areaTH': 'ริมถนนบางนา-ตราด เขตบางนา, กรุงเทพฯ',
#    'areaEN': 'Bang Na-Trat Roadside, Bang na, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.667987',
#    'long': '100.635313',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '18', 'unit': 'µg/m³'},
#     'PM10': {'value': '35', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '18'}}},
#   {'stationID': 'bkp73t',
#    'nameTH': 'มหาวิทยาลัยเกษตรศาสตร์',
#    'nameEN': 'Kasertsart University',
#    'areaTH': 'ริมถนนพหลโยธิน แยก ม.เกษตรศาสตร์ เขตจตุจักร, กรุงเทพฯ',
#    'areaEN': 'Kasertsart Intersection, Chatuchak, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.839923',
#    'long': '100.575632',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '8', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '8'}}},
#   {'stationID': 'bkp74t',
#    'nameTH': 'สำนักงานเขตดอนเมือง',
#    'nameEN': 'Don Mueng District Office, Bangkok',
#    'areaTH': 'เขตดอนเมือง, กรุงเทพฯ',
#    'areaEN': 'Don Mueng, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.910986',
#    'long': '100.594877',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '9', 'unit': 'µg/m³'},
#     'PM10': {'value': '18', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '9'}}},
#   {'stationID': 'bkp75t',
#    'nameTH': 'สำนักงานเขตสายไหม',
#    'nameEN': 'Sai Mai District Office, Bangkok',
#    'areaTH': 'ริมถนนสุขาภิบาล5 เขตสายไหม, กรุงเทพฯ',
#    'areaEN': 'Sukhaphiban 5 Roadside, Sai Mai, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.896035',
#    'long': '100.660628',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '12', 'unit': 'µg/m³'},
#     'PM10': {'value': '33', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '17'}}},
#   {'stationID': 'bkp76t',
#    'nameTH': 'สำนักงานเขตบางกะปิ',
#    'nameEN': 'Bang Kapi District Office, Bangkok',
#    'areaTH': 'ริมถนนนวมินทร์ แยกบางกะปิ เขตบางกะปิ, กรุงเทพฯ',
#    'areaEN': 'Navamin Roadside, Bang Kapi, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.766478',
#    'long': '100.647785',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '-', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '0', 'aqi': '-1'}}},
#   {'stationID': 'bkp77t',
#    'nameTH': 'แยกสวนสยาม-รามอินทรา',
#    'nameEN': 'Suan Sayam-Ram Intra Intersection',
#    'areaTH': 'แยกสวนสยาม-รามอินทรา เขตคันนายาว, กรุงเทพฯ',
#    'areaEN': 'Suan Sayam-Ram Intra Intersection Khan Na Yao, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.799395',
#    'long': '100.682464',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '9', 'unit': 'µg/m³'},
#     'PM10': {'value': '21', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '11'}}},
#   {'stationID': 'bkp78t',
#    'nameTH': 'โรงพยาบาลลาดกระบัง',
#    'nameEN': 'Lat Krabang Hospital',
#    'areaTH': 'ริมถนนลาดกระบัง เขตลาดกระบัง, กรุงเทพฯ',
#    'areaEN': 'Lat Krabang Roadside, Lat Krabang, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.72205',
#    'long': '100.784069',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '13', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '13'}}},
#   {'stationID': 'bkp79t',
#    'nameTH': 'สวนเฉลิมพระเกียรติ ร.9',
#    'nameEN': 'Chaloem Phrakiat Rama 9 Park Min buri, Bangkok',
#    'areaTH': 'ริมถนนสีหบุรานุกิจ เขตมีนบุรี, กรุงเทพฯ',
#    'areaEN': 'Sihaburanukit Roadside, Meenburi, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.813578',
#    'long': '100.73208',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '8', 'unit': 'µg/m³'},
#     'PM10': {'value': '25', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '13'}}},
#   {'stationID': 'bkp80t',
#    'nameTH': 'สำนักงานเขตหนองจอก',
#    'nameEN': 'Nong Chok District Office, Bangkok',
#    'areaTH': 'ริมถนนเลียบวารี เขตหนองจอก, กรุงเทพฯ',
#    'areaEN': 'Liap Wari Roadsire, Nong Chok, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.855362',
#    'long': '100.86267',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': '27', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '14'}}},
#   {'stationID': 'bkp81t',
#    'nameTH': 'ซีคอน สแควร์',
#    'nameEN': 'Seacon Square',
#    'areaTH': 'ริมถนนศรีนครินทร์ เขตประเวศ, กรุงเทพฯ',
#    'areaEN': 'Srinakarin Roadside, Prawet, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.695561',
#    'long': '100.647615',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '16', 'unit': 'µg/m³'},
#     'PM10': {'value': '31', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '16'}}},
#   {'stationID': 'bkp82t',
#    'nameTH': 'แยกมไหศวรรย์',
#    'nameEN': 'Mahaisawan Intersection',
#    'areaTH': 'ริมถนนรัชดาภิเษก-ท่าพระ เขตธนบุรี, กรุงเทพฯ',
#    'areaEN': 'Ratchadaphisek Roadside, Thon Buri, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.70515',
#    'long': '100.48465',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '10'}}},
#   {'stationID': 'bkp83t',
#    'nameTH': 'ห้องสมุดใต้สะพานสมเด็จพระเจ้าตากสิน',
#    'nameEN': 'Library under King Taksin Bridge',
#    'areaTH': 'ริมถนนเจริญนคร เขตคลองสาน, กรุงเทพฯ',
#    'areaEN': 'Charoen Nakorn Roadside, Klong San, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.719705',
#    'long': '100.508782',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '13', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '13'}}},
#   {'stationID': 'bkp84t',
#    'nameTH': 'สี่แยกท่าพระ',
#    'nameEN': 'Tha phra Intersection',
#    'areaTH': 'ริมถนนแยกท่าพระ เขตบางกอกใหญ่, กรุงเทพฯ',
#    'areaEN': 'Tha phra Intersection, Bangkok Yai, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.729431',
#    'long': '100.474373',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '17', 'unit': 'µg/m³'},
#     'PM10': {'value': '13', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '17'}}},
#   {'stationID': 'bkp85t',
#    'nameTH': 'สถานีตำรวจรถไฟบางกอกน้อย',
#    'nameEN': 'Bangkok Noi Train Police Station',
#    'areaTH': 'ริมถนนซอยนิคมบ้านพักรถไฟธนบุรี 5 เขตบางกอกน้อย, กรุงเทพฯ',
#    'areaEN': 'Soi Nikhom Banphak Rodfai Thonburi5, Bangkok Noi, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.759619',
#    'long': '100.481137',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '6', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '6'}}},
#   {'stationID': 'bkp86t',
#    'nameTH': 'ถนนพุทธมณฑลสาย 1 ตัดกับถนนบรมราชชนนี',
#    'nameEN': 'Phutthamonthon 1 - Borommaratchachonnani Intersection',
#    'areaTH': 'ริมถนนพุทธมณฑล 1 เขตตลิ่งชัน, กรุงเทพฯ',
#    'areaEN': 'Phutthamonthon 1 Roadside, Taling Chan, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.780778',
#    'long': '100.426727',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': '62', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '2', 'aqi': '35'}}},
#   {'stationID': 'bkp87t',
#    'nameTH': 'ตลาดธนบุรีสนามหลวง 2',
#    'nameEN': 'Thon Buri Market Sanam Luang 2',
#    'areaTH': 'ริมถนนคลองทวีวัฒนา เขตทวีวัฒนา, กรุงเทพฯ',
#    'areaEN': 'Klong Thawi Watthana Roadside, Thawi Watthana, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.746257',
#    'long': '100.355099',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '12', 'unit': 'µg/m³'},
#     'PM10': {'value': '14', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '12'}}},
#   {'stationID': 'bkp88t',
#    'nameTH': 'มหาวิทยาลัยสยาม',
#    'nameEN': 'Siam University',
#    'areaTH': 'ริมถนนเพชรเกษม เขตภาษีเจริญ, กรุงเทพฯ',
#    'areaEN': 'Petchkasem Roadside, Phasi Charoen, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.718689',
#    'long': '100.45391',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '9', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '9'}}},
#   {'stationID': 'bkp89t',
#    'nameTH': 'ริมถนนมาเจริญ เพชรเกษม 8, เขตหนองแขม',
#    'nameEN': 'Ma Charean Roadside, Petcha Kasem 8, Nong Khaem',
#    'areaTH': 'ริมถนนมาเจริญ เพชรเกษม 81 เขตหนองแขม, กรุงเทพฯ',
#    'areaEN': 'Ma Charean Roadside Nong Khaem, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.705582',
#    'long': '100.343164',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '15', 'unit': 'µg/m³'},
#     'PM10': {'value': '-', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '15'}}},
#   {'stationID': 'bkp90t',
#    'nameTH': 'ตลาดบางบอน 5',
#    'nameEN': 'Bang Bon 5 Market',
#    'areaTH': 'ริมถนนเอกชัย เขตบางบอน, กรุงเทพฯ',
#    'areaEN': 'Ekkachai Roadside, Bang Bon, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.639165',
#    'long': '100.372958',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '14', 'unit': 'µg/m³'},
#     'PM10': {'value': '22', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '14'}}},
#   {'stationID': 'bkp91t',
#    'nameTH': 'มหาวิทยาลัยเทคโนโลยีพระจอมเกล้าธนบุรี',
#    'nameEN': "King Mongkut's University of Technology Thonburi ",
#    'areaTH': 'ริมถนนประชาอุทิศ เขตทุ่งครุ, กรุงเทพฯ',
#    'areaEN': 'Pracha Uthit Roadside, Thung Khru, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.651004',
#    'long': '100.496673',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': '19', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '10'}}},
#   {'stationID': 'bkp92t',
#    'nameTH': 'สำนักงานเขตพระนคร',
#    'nameEN': 'Phra Nakhon District Office, Bangkok',
#    'areaTH': 'ริมถนนสามเสน เขตพระนคร, กรุงเทพฯ',
#    'areaEN': 'Samsen Roadside, Phra Nakhon, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.76415',
#    'long': '100.499077',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '15', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '15'}}},
#   {'stationID': 'bkp93t',
#    'nameTH': 'สำนักงานเขตห้วยขวาง',
#    'nameEN': 'Huai Khwang District Office, Bangkok',
#    'areaTH': 'เขตห้วยขวาง, กรุงเทพฯ',
#    'areaEN': 'Huai Khwang, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.77682',
#    'long': '100.579543',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '-', 'unit': 'µg/m³'},
#     'PM10': {'value': '16', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '8'}}},
#   {'stationID': 'bkp94t',
#    'nameTH': 'สำนักงานเขตคลองเตย',
#    'nameEN': 'Khlong Toei District Office, Bangkok',
#    'areaTH': 'แขวงคลองเตย เขตคลองเตย, กรุงเทพฯ',
#    'areaEN': 'Khlong Toei, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.708488',
#    'long': '100.583747',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '10'}}},
#   {'stationID': 'bkp95t',
#    'nameTH': 'สำนักงานเขตบางซื่อ',
#    'nameEN': 'Bang Sue District Office, Bangkok',
#    'areaTH': 'แขวงบางซื่อ เขตบางซื่อ, กรุงเทพฯ',
#    'areaEN': 'Bang Sue, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.809596',
#    'long': '100.537883',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '9', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '9'}}},
#   {'stationID': 'bkp96t',
#    'nameTH': 'สำนักงานเขตลาดพร้าว',
#    'nameEN': 'Ladphrao District Office, Bangkok',
#    'areaTH': 'เขตลาดพร้าว, กรุงเทพฯ',
#    'areaEN': 'Ladphrao, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.803587',
#    'long': '100.607535',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '8', 'unit': 'µg/m³'},
#     'PM10': {'value': '21', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '11'}}},
#   {'stationID': 'bkp97t',
#    'nameTH': 'สำนักงานเขตหลักสี่',
#    'nameEN': 'Lak Si District Office, Bangkok',
#    'areaTH': 'แขวงทุ่งสองห้อง เขตหลักสี่, กรุงเทพฯ',
#    'areaEN': 'Thung Song Hong, Lak Si, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.887395',
#    'long': '100.579247',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '5', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '5'}}},
#   {'stationID': 'bkp98t',
#    'nameTH': 'สำนักงานเขตบางเขน',
#    'nameEN': 'Bang Khen District Office, Bangkok',
#    'areaTH': 'ริมถนนพหลโยธิน เขตบางเขน, กรุงเทพฯ',
#    'areaEN': 'Phahon Yothin Roadside, Bang Khen, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.873603',
#    'long': '100.595839',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '9', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '9'}}},
#   {'stationID': 'bkp99t',
#    'nameTH': 'สำนักงานเขตสะพานสูง',
#    'nameEN': 'Saphan Sung District Office, Bangkok',
#    'areaTH': 'เขตสะพานสูง, กรุงเทพฯ',
#    'areaEN': 'Saphan Sung, Bangkok',
#    'stationType': 'BKK',
#    'lat': '13.768892',
#    'long': '100.685743',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '6', 'unit': 'µg/m³'},
#     'PM10': {'value': '13', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '7'}}},
#   {'stationID': '79t',
#    'nameTH': 'สถานีอุตุนิยมวิทยา จ.กาญจนบุรี',
#    'nameEN': 'Kanchanaburi Meteorological Station',
#    'areaTH': 'ต.บ้านเหนือ อ.เมือง, กาญจนบุรี',
#    'areaEN': 'Ban Nuea, Mueang, Kanchanaburi',
#    'stationType': 'GROUND',
#    'lat': '14.022376',
#    'long': '99.536195',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '17:00',
#     'PM25': {'value': '4', 'unit': 'µg/m³'},
#     'PM10': {'value': '10', 'unit': 'µg/m³'},
#     'O3': {'value': '10', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '0', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '7'}}},
#   {'stationID': 'o21',
#    'nameTH': ' ที่ว่าการอำเภอเมืองกำแพงเพชร',
#    'nameEN': 'District Hall, Kamphaeng Phet',
#    'areaTH': 'ต.ในเมือง อ.เมือง, กำแพงเพชร',
#    'areaEN': 'Mueang, Kamphaeng Phet',
#    'stationType': 'MOBILE',
#    'lat': '16.48515',
#    'long': '99.524454',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '4', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '4'}}},
#   {'stationID': '46t',
#    'nameTH': 'ส่วนอุทกวิทยา สำนักงานทรัพยากรน้ำภาคที่4 ขอนแก่น',
#    'nameEN': 'Hydrogeological Group Water Resources Regional Office4 khonkaen',
#    'areaTH': 'ต.ในเมือง อ.เมือง, ขอนแก่น',
#    'areaEN': 'Nai Mueang, Mueang, Khon Kaen',
#    'stationType': 'GROUND',
#    'lat': '16.445329',
#    'long': '102.835251',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '14:00',
#     'PM25': {'value': '13', 'unit': 'µg/m³'},
#     'PM10': {'value': '32', 'unit': 'µg/m³'},
#     'O3': {'value': '-', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '16'}}},
#   {'stationID': '60t',
#    'nameTH': 'สำนักงานเทศบาลตำบลทุ่งสะเดา',
#    'nameEN': 'Municipality Office Tungsadao',
#    'areaTH': 'ต.วังเย็น อ.แปลงยาว, ฉะเชิงเทรา',
#    'areaEN': 'Wang Yen, Plaeng Yao, Chachoengsao',
#    'stationType': 'GROUND',
#    'lat': '13.588554',
#    'long': '101.286359',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': '26', 'unit': 'µg/m³'},
#     'O3': {'value': '11', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '1', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '13'}}},
#   {'stationID': '32t',
#    'nameTH': 'สนามกีฬาเทศบาลแหลมฉบัง ',
#    'nameEN': 'Laem Chabang Municipal Stadium',
#    'areaTH': 'ต.ทุ่งสุขลา อ.ศรีราชา, ชลบุรี',
#    'areaEN': 'Thung Sukhla, Si Racha, Chon buri',
#    'stationType': 'GROUND',
#    'lat': '13.119214',
#    'long': '100.918596',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '7', 'unit': 'µg/m³'},
#     'PM10': {'value': '16', 'unit': 'µg/m³'},
#     'O3': {'value': '25', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '18'}}},
#   {'stationID': '33t',
#    'nameTH': 'โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเขาหิน',
#    'nameEN': 'Health Promotion Hospital Bankhaohin',
#    'areaTH': 'ต.บ่อวิน อ.ศรีราชา, ชลบุรี',
#    'areaEN': 'Bo Win, Si Racha, Chon buri',
#    'stationType': 'GROUND',
#    'lat': '13.054551',
#    'long': '101.098128',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '6', 'unit': 'µg/m³'},
#     'PM10': {'value': '18', 'unit': 'µg/m³'},
#     'O3': {'value': '22', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '16'}}},
#   {'stationID': '34t',
#    'nameTH': 'สำนักงานสิ่งแวดล้อมภาคที่ 13 ',
#    'nameEN': 'Environment Agency Section 13, Chonburi',
#    'areaTH': 'ต.บ้านสวน อ.เมือง, ชลบุรี',
#    'areaEN': 'Ban Suan, Mueang, Chon Buri',
#    'stationType': 'GROUND',
#    'lat': '13.355065',
#    'long': '100.977777',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '7', 'unit': 'µg/m³'},
#     'PM10': {'value': '18', 'unit': 'µg/m³'},
#     'O3': {'value': '23', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '17', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '16'}}},
#   {'stationID': '93t',
#    'nameTH': 'วิทยาลัยสารพัดช่างตรัง',
#    'nameEN': 'Polytechnic College, Trang ',
#    'areaTH': 'ต.นาตาล่วง อ.เมือง, ตรัง',
#    'areaEN': 'Na Ta Luang Subdistrict, Mueang District, Trang',
#    'stationType': 'GROUND',
#    'lat': '7.570238',
#    'long': '99.588743',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '13', 'unit': 'µg/m³'},
#     'PM10': {'value': '23', 'unit': 'µg/m³'},
#     'O3': {'value': '17', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '0', 'unit': 'ppb'},
#     'SO2': {'value': '0', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '13'}}},
#   {'stationID': '87t',
#    'nameTH': 'สนามกีฬากลางจังหวัดตราด',
#    'nameEN': 'Trat Provincial Central Stadium',
#    'areaTH': 'ต.บางพระ อ.เมือง, ตราด',
#    'areaEN': 'Bang Phra, Mueang, Trat',
#    'stationType': 'GROUND',
#    'lat': '12.234862',
#    'long': '102.523721',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '8', 'unit': 'µg/m³'},
#     'PM10': {'value': '26', 'unit': 'µg/m³'},
#     'O3': {'value': '27', 'unit': 'ppb'},
#     'CO': {'value': '0.24', 'unit': 'ppm'},
# ...
#    'stationType': 'GROUND',
#    'lat': '13.599149',
#    'long': '100.597345',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '17', 'unit': 'µg/m³'},
#     'PM10': {'value': '29', 'unit': 'µg/m³'},
#     'O3': {'value': '22', 'unit': 'ppb'},
#     'CO': {'value': '0.46', 'unit': 'ppm'},
#     'NO2': {'value': '31', 'unit': 'ppb'},
#     'SO2': {'value': '1', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '17'}}},
#   {'stationID': '19t',
#    'nameTH': 'การเคหะชุมชนเมืองใหม่บางพลี ',
#    'nameEN': 'National Housing Authority Bangplee',
#    'areaTH': 'ต.บางเสาธง อ.บางเสาธง, สมุทรปราการ',
#    'areaEN': 'Bang Sao Thong, Bang Sao Thong, Samut Prakan\xa0',
#    'stationType': 'GROUND',
#    'lat': '13.5705',
#    'long': '100.786287',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '12', 'unit': 'µg/m³'},
#     'PM10': {'value': '23', 'unit': 'µg/m³'},
#     'O3': {'value': '27', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '7', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '19'}}},
#   {'stationID': 'o27',
#    'nameTH': 'สวนศรีนครเขื่อนขันธ์',
#    'nameEN': 'Sri Nakhon Khuean Khan Park',
#    'areaTH': 'ต.บางกะเจ้า อ.พระประแดง, สมุทรปราการ',
#    'areaEN': ' Bang Krachao Subdistrict, Phra Pradaeng, Samut Prakan',
#    'stationType': 'MOBILE',
#    'lat': '13.696681',
#    'long': '100.563631',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '17:00',
#     'PM25': {'value': '5', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '5'}}},
#   {'stationID': '84t',
#    'nameTH': 'สำนักงานสาธารณสุขจังหวัดสมุทรสงคราม',
#    'nameEN': 'Samut Songkhram Health Office',
#    'areaTH': ' ต.ลาดใหญ่ อ.เมือง, สมุทรสงคราม',
#    'areaEN': 'Mueang, Samut Songkhram',
#    'stationType': 'GROUND',
#    'lat': '13.428581',
#    'long': '100.024664',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '4', 'unit': 'µg/m³'},
#     'PM10': {'value': '10', 'unit': 'µg/m³'},
#     'O3': {'value': '30', 'unit': 'ppb'},
#     'CO': {'value': '0.75', 'unit': 'ppm'},
#     'NO2': {'value': '10', 'unit': 'ppb'},
#     'SO2': {'value': '1', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '21'}}},
#   {'stationID': '14t',
#    'nameTH': 'แขวงการทางสมุทรสาคร ',
#    'nameEN': 'Highway District',
#    'areaTH': 'ต.อ้อมน้อย อ.กระทุ่มแบน, สมุทรสาคร',
#    'areaEN': 'Om Noi, Krathum Baen, Samut Sakhon',
#    'stationType': 'GROUND',
#    'lat': '13.705458',
#    'long': '100.315675',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '17:00',
#     'PM25': {'value': '8', 'unit': 'µg/m³'},
#     'PM10': {'value': '22', 'unit': 'µg/m³'},
#     'O3': {'value': '21', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '15'}}},
#   {'stationID': '27t',
#    'nameTH': 'โรงเรียนสมุทรสาครวิทยาลัย',
#    'nameEN': 'Samut Sakhon Wittayalai School',
#    'areaTH': 'ต.มหาชัย อ.เมือง, สมุทรสาคร',
#    'areaEN': 'Maha Chai, Mueang, Samut Sakhon',
#    'stationType': 'GROUND',
#    'lat': '13.550478',
#    'long': '100.264254',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '13', 'unit': 'µg/m³'},
#     'PM10': {'value': '24', 'unit': 'µg/m³'},
#     'O3': {'value': '17', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '13'}}},
#   {'stationID': '24t',
#    'nameTH': 'สถานีตำรวจภูธรตำบลหน้าพระลาน ',
#    'nameEN': 'Na Phralan Police Station ',
#    'areaTH': 'ต.หน้าพระลาน อ.เฉลิมพระเกียรติ, สระบุรี',
#    'areaEN': 'Na Phra Lan, Chaloem Phra Kiat, Saraburi',
#    'stationType': 'GROUND',
#    'lat': '14.685833',
#    'long': '100.871996',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '13', 'unit': 'µg/m³'},
#     'PM10': {'value': '76', 'unit': 'µg/m³'},
#     'O3': {'value': '18', 'unit': 'ppb'},
#     'CO': {'value': '0.75', 'unit': 'ppm'},
#     'NO2': {'value': '42', 'unit': 'ppb'},
#     'SO2': {'value': '2', 'unit': 'ppb'},
#     'AQI': {'Level': '2', 'aqi': '47'}}},
#   {'stationID': '25t',
#    'nameTH': 'สถานีดับเพลิงพระลักษณ์',
#    'nameEN': 'Khao Noi Fire Station',
#    'areaTH': 'ต.ปากเพรียว อ.เมือง, สระบุรี',
#    'areaEN': 'Pak Phriao, Mueang Saraburi, Saraburi',
#    'stationType': 'GROUND',
#    'lat': '14.526343',
#    'long': '100.926047',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '7', 'unit': 'µg/m³'},
#     'PM10': {'value': '22', 'unit': 'µg/m³'},
#     'O3': {'value': '28', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': '13', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '20'}}},
#   {'stationID': '71t',
#    'nameTH': 'สวนกาญจนาภิเษก ร.9 (ฝั่งสวนหิน)',
#    'nameEN': 'Kanjanapisek Park',
#    'areaTH': 'ต.อรัญประเทศ อ.อรัญประเทศ, สระแก้ว',
#    'areaEN': 'Aranyaprathet, Aranyaprathet, Sa Kaeo',
#    'stationType': 'GROUND',
#    'lat': '13.691047',
#    'long': '102.510442',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '4', 'unit': 'µg/m³'},
#     'PM10': {'value': '11', 'unit': 'µg/m³'},
#     'O3': {'value': '28', 'unit': 'ppb'},
#     'CO': {'value': '0.33', 'unit': 'ppm'},
#     'NO2': {'value': '3', 'unit': 'ppb'},
#     'SO2': {'value': '1', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '20'}}},
#   {'stationID': '85t',
#    'nameTH': 'สนามกีฬากลางจังหวัดสุพรรณบุรี',
#    'nameEN': 'Suphan Buri Provincial Central Stadium',
#    'areaTH': 'ต.ดอนกำยาน อ.เมือง, สุพรรณบุรี',
#    'areaEN': 'Don Kamyan, Mueang, Suphun Buri',
#    'stationType': 'GROUND',
#    'lat': '14.476214',
#    'long': '100.086095',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '5', 'unit': 'µg/m³'},
#     'PM10': {'value': '11', 'unit': 'µg/m³'},
#     'O3': {'value': '22', 'unit': 'ppb'},
#     'CO': {'value': '0.66', 'unit': 'ppm'},
#     'NO2': {'value': '7', 'unit': 'ppb'},
#     'SO2': {'value': '1', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '16'}}},
#   {'stationID': '42t',
#    'nameTH': 'สำนักงานสิ่งแวดล้อมภาคที่ 14',
#    'nameEN': 'Environment Agency Section 14, Surat Thani',
#    'areaTH': 'ต.มะขามเตี้ย อ.เมือง, สุราษฎร์ธานี',
#    'areaEN': 'Makham Tia, Mueang, Surat Thani',
#    'stationType': 'GROUND',
#    'lat': '9.126057',
#    'long': '99.325355',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '17', 'unit': 'µg/m³'},
#     'PM10': {'value': '-', 'unit': 'µg/m³'},
#     'O3': {'value': '-', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '17'}}},
#   {'stationID': 'o28',
#    'nameTH': 'สำนักงานเทศบาลเมืองสุโขทัยธานี',
#    'nameEN': 'Municipality Office, Sukhothai',
#    'areaTH': 'ต.ธานี อ.เมือง, สุโขทัย',
#    'areaEN': 'Mueang, Sukhothai',
#    'stationType': 'MOBILE',
#    'lat': '17.014167',
#    'long': '99.821667',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '3', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '3'}}},
#   {'stationID': '82t',
#    'nameTH': 'สวนสาธารณะหนองถิ่น',
#    'nameEN': 'Nong Thin Public Park, Nong Khai',
#    'areaTH': ' ต.มีชัย อ.เมือง, หนองคาย',
#    'areaEN': 'Meechai, Meuang, Nong Khai',
#    'stationType': 'GROUND',
#    'lat': '17.87748',
#    'long': '102.728925',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '6', 'unit': 'µg/m³'},
#     'PM10': {'value': '11', 'unit': 'µg/m³'},
#     'O3': {'value': '28', 'unit': 'ppb'},
#     'CO': {'value': '0.29', 'unit': 'ppm'},
#     'NO2': {'value': '7', 'unit': 'ppb'},
#     'SO2': {'value': '2', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '20'}}},
#   {'stationID': '91t',
#    'nameTH': 'สวนสาธารณะหนองประจักษ์ อุดรธานี',
#    'nameEN': 'Nong Prajak Public Park, Udon Thani',
#    'areaTH': 'ต.หมากแข้ง อ.เมือง, อุดรธานี',
#    'areaEN': 'Mak Khaeng, Mueang, Udon Thani',
#    'stationType': 'GROUND',
#    'lat': '17.414174',
#    'long': '102.780926',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '3', 'unit': 'µg/m³'},
#     'PM10': {'value': '8', 'unit': 'µg/m³'},
#     'O3': {'value': '30', 'unit': 'ppb'},
#     'CO': {'value': '0.47', 'unit': 'ppm'},
#     'NO2': {'value': '3', 'unit': 'ppb'},
#     'SO2': {'value': '1', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '21'}}},
#   {'stationID': '92t',
#    'nameTH': 'สวนมหามงคลเฉลิมพระชนมพรรษา 6 รอบ 5 ธันวาคม 2552 อุตรดิตถ์',
#    'nameEN': '72nd Anniversary King Bhumibol Public Park, Uttaradit',
#    'areaTH': 'ต.ท่าอิฐ อ.เมือง, อุตรดิตถ์',
#    'areaEN': 'Tha It, Mueang, Uttaradit',
#    'stationType': 'GROUND',
#    'lat': '17.631352',
#    'long': '100.09896',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '7', 'unit': 'µg/m³'},
#     'PM10': {'value': '21', 'unit': 'µg/m³'},
#     'O3': {'value': '22', 'unit': 'ppb'},
#     'CO': {'value': '0.22', 'unit': 'ppm'},
#     'NO2': {'value': '7', 'unit': 'ppb'},
#     'SO2': {'value': '1', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '16'}}},
#   {'stationID': 'o25',
#    'nameTH': 'ศาลากลางจ.อุทัยธานี',
#    'nameEN': 'Uthai Thani Provincial Hall',
#    'areaTH': 'ต.อุทัยใหม่ อ.เมือง, อุทัยธานี',
#    'areaEN': 'Mueang, Uthai Thani',
#    'stationType': 'MOBILE',
#    'lat': '15.373638',
#    'long': '100.038725',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '4', 'unit': 'µg/m³'},
#     'PM10': {'value': 'N/A', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': 'N/A', 'unit': 'ppm'},
#     'NO2': {'value': 'N/A', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '4'}}},
#   {'stationID': '83t',
#    'nameTH': 'ศูนย์แสดงและจำหน่ายสินค้า OTOP จังหวัดอุบลราชธานี',
#    'nameEN': 'OTOP Center, Ubon Ratchathani',
#    'areaTH': 'ต.ในเมือง อ.เมือง, อุบลราชธานี',
#    'areaEN': 'Mueang, Ubon Ratchathani',
#    'stationType': 'GROUND',
#    'lat': '15.245413',
#    'long': '104.846219',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '3', 'unit': 'µg/m³'},
#     'PM10': {'value': '9', 'unit': 'µg/m³'},
#     'O3': {'value': '22', 'unit': 'ppb'},
#     'CO': {'value': '0.31', 'unit': 'ppm'},
#     'NO2': {'value': '6', 'unit': 'ppb'},
#     'SO2': {'value': '0', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '16'}}},
#   {'stationID': '57t',
#    'nameTH': 'สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัดเชียงราย',
#    'nameEN': 'Natural Resources and Environment Office, Chiangrai',
#    'areaTH': 'ต.เวียง อ.เมือง, เชียงราย',
#    'areaEN': 'Wiang, Meuang, Chiang Rai',
#    'stationType': 'GROUND',
#    'lat': '19.909242',
#    'long': '99.823357',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '5', 'unit': 'µg/m³'},
#     'PM10': {'value': '10', 'unit': 'µg/m³'},
#     'O3': {'value': '29', 'unit': 'ppb'},
#     'CO': {'value': '0.44', 'unit': 'ppm'},
#     'NO2': {'value': '2', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '21'}}},
#   {'stationID': '73t',
#    'nameTH': 'สำนักงานสาธารณสุขแม่สาย',
#    'nameEN': 'Maesai Health Office',
#    'areaTH': 'ต.เวียงพางคำ อ.แม่สาย, เชียงราย',
#    'areaEN': 'Wiang Phang Kham, Mae Sai, Chiang Rai',
#    'stationType': 'GROUND',
#    'lat': '20.427325',
#    'long': '99.883842',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '9', 'unit': 'µg/m³'},
#     'PM10': {'value': '19', 'unit': 'µg/m³'},
#     'O3': {'value': '26', 'unit': 'ppb'},
#     'CO': {'value': '0.37', 'unit': 'ppm'},
#     'NO2': {'value': '7', 'unit': 'ppb'},
#     'SO2': {'value': '1', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '19'}}},
#   {'stationID': '35t',
#    'nameTH': 'ศูนย์ราชการจังหวัดเชียงใหม่ ',
#    'nameEN': 'City Hall, Chiangmai',
#    'areaTH': 'ต.ช้างเผือก อ.เมือง, เชียงใหม่',
#    'areaEN': 'Chang Phueak, Meuang, Chiang Mai',
#    'stationType': 'GROUND',
#    'lat': '18.840633',
#    'long': '98.969661',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '10', 'unit': 'µg/m³'},
#     'PM10': {'value': '17', 'unit': 'µg/m³'},
#     'O3': {'value': '26', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '0', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '19'}}},
#   {'stationID': '36t',
#    'nameTH': 'โรงเรียนยุพราชวิทยาลัย ',
#    'nameEN': 'Yupparaj Wittayalai School',
#    'areaTH': 'ต.ศรีภูมิ อ.เมือง, เชียงใหม่',
#    'areaEN': 'Si Phum, Meuang, Chiang Mai',
#    'stationType': 'GROUND',
#    'lat': '18.7909205',
#    'long': '98.9881062',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '4', 'unit': 'µg/m³'},
#     'PM10': {'value': '13', 'unit': 'µg/m³'},
#     'O3': {'value': 'N/A', 'unit': 'ppb'},
#     'CO': {'value': '0.82', 'unit': 'ppm'},
#     'NO2': {'value': '-', 'unit': 'ppb'},
#     'SO2': {'value': '1', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '7'}}},
#   {'stationID': '72t',
#    'nameTH': 'สวนสาธารณะเฉลิมพระเกียรติ 60 พรรษามหาราชินี จังหวัดเลย',
#    'nameEN': '60th Anniversary Queen Sirikit Public Park, Loei',
#    'areaTH': 'ต.กุดป่อง อ.เมือง, เลย',
#    'areaEN': 'Kut Pong Subdistrict, Mueang District, Loei',
#    'stationType': 'GROUND',
#    'lat': '17.48462',
#    'long': '101.732734',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-09-27',
#     'time': '17:00',
#     'PM25': {'value': '4', 'unit': 'µg/m³'},
#     'PM10': {'value': '12', 'unit': 'µg/m³'},
#     'O3': {'value': '16', 'unit': 'ppb'},
#     'CO': {'value': '0.01', 'unit': 'ppm'},
#     'NO2': {'value': '4', 'unit': 'ppb'},
#     'SO2': {'value': '0', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '11'}}},
#   {'stationID': '69t',
#    'nameTH': 'อุตุนิยมวิทยาจังหวัดแพร่',
#    'nameEN': 'Meteorology Center, Phrae',
#    'areaTH': 'ต.นาจักร อ.เมือง, แพร่',
#    'areaEN': 'Na Chak, Meuang, Phrae',
#    'stationType': 'GROUND',
#    'lat': '18.128928',
#    'long': '100.162345',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '8', 'unit': 'µg/m³'},
#     'PM10': {'value': '17', 'unit': 'µg/m³'},
#     'O3': {'value': '27', 'unit': 'ppb'},
#     'CO': {'value': '0.50', 'unit': 'ppm'},
#     'NO2': {'value': '10', 'unit': 'ppb'},
#     'SO2': {'value': '-', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '19'}}},
#   {'stationID': '58t',
#    'nameTH': 'สำนักงานทรัพยากรธรรมชาติและสิ่งแวดล้อมจังหวัดแม่ฮ่องสอน',
#    'nameEN': 'Natural Resources and Environment Office, Mae Hongson',
#    'areaTH': 'ต.จองคำ อ.เมือง, แม่ฮ่องสอน',
#    'areaEN': 'Chong Kham, Meuang, Mae Hong Son',
#    'stationType': 'GROUND',
#    'lat': '19.304686',
#    'long': '97.970999',
#    'forecast': [],
#    'LastUpdate': {'date': '2021-10-17',
#     'time': '18:00',
#     'PM25': {'value': '4', 'unit': 'µg/m³'},
#     'PM10': {'value': '9', 'unit': 'µg/m³'},
#     'O3': {'value': '14', 'unit': 'ppb'},
#     'CO': {'value': '-', 'unit': 'ppm'},
#     'NO2': {'value': '2', 'unit': 'ppb'},
#     'SO2': {'value': 'N/A', 'unit': 'ppb'},
#     'AQI': {'Level': '1', 'aqi': '10'}}}]}
