# %% [markdown]
# <a href="https://colab.research.google.com/github/Tuchsanai/152-478-Introduction-to-Deep-Learning-for-Artificial-Intelligence-Engineering/blob/main/google_tts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ปรับจาก [ต้นฉบับ](https://colab.research.google.com/drive/15mo6GPYq1tKRsQh8VK0fsudRKjU7Rt-a) ของ อ.ประเสริฐ เล็กน้อย

# %% [markdown]
# # Google Text-to-Speech
# * doc: https://gtts.readthedocs.io/en/latest/module.html
# * install: pip install gTTS

# %%
# !pip install gtts
# Out:
# Requirement already satisfied: gtts in /usr/local/lib/python3.7/dist-packages (2.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gtts) (2.23.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from gtts) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gtts) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (2021.10.8)

# %%
from IPython.display import Audio
import gtts
from gtts import gTTS

# %% [markdown]
# ## รหัสภาษา

# %%
gtts.lang.tts_langs()
# Out:
# {'af': 'Afrikaans',
#  'ar': 'Arabic',
#  'bg': 'Bulgarian',
#  'bn': 'Bengali',
#  'bs': 'Bosnian',
#  'ca': 'Catalan',
#  'cs': 'Czech',
#  'cy': 'Welsh',
#  'da': 'Danish',
#  'de': 'German',
#  'el': 'Greek',
#  'en': 'English',
#  'eo': 'Esperanto',
#  'es': 'Spanish',
#  'et': 'Estonian',
#  'fi': 'Finnish',
#  'fr': 'French',
#  'gu': 'Gujarati',
#  'hi': 'Hindi',
#  'hr': 'Croatian',
#  'hu': 'Hungarian',
#  'hy': 'Armenian',
#  'id': 'Indonesian',
#  'is': 'Icelandic',
#  'it': 'Italian',
#  'ja': 'Japanese',
#  'jw': 'Javanese',
#  'km': 'Khmer',
#  'kn': 'Kannada',
#  'ko': 'Korean',
#  'la': 'Latin',
#  'lv': 'Latvian',
#  'mk': 'Macedonian',
#  'ml': 'Malayalam',
#  'mr': 'Marathi',
#  'my': 'Myanmar (Burmese)',
#  'ne': 'Nepali',
#  'nl': 'Dutch',
#  'no': 'Norwegian',
#  'pl': 'Polish',
#  'pt': 'Portuguese',
#  'ro': 'Romanian',
#  'ru': 'Russian',
#  'si': 'Sinhala',
#  'sk': 'Slovak',
#  'sq': 'Albanian',
#  'sr': 'Serbian',
#  'su': 'Sundanese',
#  'sv': 'Swedish',
#  'sw': 'Swahili',
#  'ta': 'Tamil',
#  'te': 'Telugu',
#  'th': 'Thai',
#  'tl': 'Filipino',
#  'tr': 'Turkish',
#  'uk': 'Ukrainian',
#  'ur': 'Urdu',
#  'vi': 'Vietnamese',
#  'zh': 'Chinese (Mandarin)',
#  'zh-CN': 'Chinese',
#  'zh-TW': 'Chinese (Mandarin/Taiwan)'}

# %% [markdown]
# ## การใช้ gTTS

# %%
tts = gTTS('hello', lang='en')
tts.save('speech.mp3')  # save to a file

# %%
tts    # ฟังเลย โดยไม่ต้อง save
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts = gTTS('สวัสดีครับ', lang='th')
tts
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts = gTTS('แม้นใครรักรักมั่งชังชังตอบ ให้รอบคอบคิดอ่านนะหลานหนา รู้สิ่งไรไม่สู้รู้วิชา รู้รักษาตัวรอดเป็นยอดดี', lang='th')
tts
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts = gTTS('อันอ้อยตาลหวานลิ้นแล้วสิ้นซาก แต่ลมปากหวานหูไม่รู้หาย ถึงเจ็บอื่นหมื่นแสนไม่แคลนคลาย เจ็บเจียนตายก็เพราะเหน็บให้เจ็บใจ', lang='th')
tts
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts = gTTS('แล้วสอนว่าอย่าไว้ใจในมนุษย์ มันแสนสุดลึก ล้ำเหลือกำหนด ถึงเถาวัลย์พันเกี่ยวที่เลี้ยว ลด ก็ไม่คดเหมือนหนึ่งในน้ำใจคน', lang='th')
tts
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts.save('speech3.mp3')  # save to a file

# %%
gTTS('ถึงม้วยดินสิ้นฟ้ามหาสมุทร ไม่สิ้นสุดความรักสมัครสมาน', lang='th')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
gTTS('こんにちは', lang='ja')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
gTTS('非常感谢你', lang='zh-cn')
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
gTTS('北，南，东，西', lang='zh-cn')
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## การเปิดเล่นไฟล์เสียงโดยตรงบน Jupyter Notebook

# %%
Audio('speech3.mp3', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
