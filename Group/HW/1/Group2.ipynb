# %%
import os 
import numpy as np
from skimage import io

# %%
url_sky = "https://raw.githubusercontent.com/Tuchsanai/152-478-Introduction-to-Deep-Learning-for-Artificial-Intelligence-Engineering/main/02_Crash-NumPy/skyimg.jpg"
img      = io.imread(url_sky) 
img.shape
# Out:
# (417, 626, 3)

# %%
io.imsave('skyimg.jpg',img)

# %%
peerayut = "/content/drive/MyDrive/peerayut.jpg"
netitorn ="/content/drive/MyDrive/netitorn.jpg"
titikarn ="/content/drive/MyDrive/titikarn.jpg"
tritep   ="/content/drive/MyDrive/tritep.jpg"
siwanart ="/content/drive/MyDrive/siwanart.jpg"
lotto    ="/content/drive/MyDrive/S__99598350.jpg"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = io.imread(peerayut) 
img.shape
# Out:
# (514, 402, 3)

# %%
io.imsave("peerayut.jpg",img)

# %%
img = io.imread(netitorn) 
img.shape
# Out:
# (402, 397, 3)

# %%
io.imsave("netitorn.jpg",img)

# %%
img = io.imread(titikarn) 
img.shape
# Out:
# (503, 381, 3)

# %%
io.imsave("titikarn.jpg",img)

# %%
img = io.imread(tritep) 
img.shape
# Out:
# (414, 405, 3)

# %%
io.imsave("tritep.jpg",img)

# %%
img = io.imread(siwanart) 
img.shape
# Out:
# (410, 394, 3)

# %%
io.imsave("siwanart.jpg",img)

# %%
img = io.imread(lotto) 
img.shape
# Out:
# (1478, 1108, 3)

# %%
io.imsave("lotto.jpg",img)

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(10, 10))

plt.imshow(img)

# %%
from PIL import Image

import numpy as np
image = io.imread(lotto) 

# Store height and width of the image
height, width = image.shape[:2]


quarter_height, quarter_width = 0.2*height, 0.2*width

#       | 1 0 Tx |
#  T  = | 0 1 Ty |

# T is our translation matrix
T = np.float32([[1, 0, quarter_width], [0, 1,quarter_height]])

print(height, width)

T
# Out:
# 1478 1108
# array([[  1. ,   0. , 221.6],
#        [  0. ,   1. , 295.6]], dtype=float32)

# %%
# We use warpAffine to transform the image using the matrix, T
img_translation = cv2.warpAffine(image, T, (width, height))

# %%
from PIL import Image

import numpy as np
image = io.imread(lotto) 
# Store height and width of the image
height, width = image.shape[:2]

# Divide by two to rototate the image around its centre
rotation_matrix = cv2.getRotationMatrix2D((0.5*width, 0.2*height), 132.0, .5)


rotation_matrix
# Out:
# array([[-3.34565303e-01,  3.71572413e-01,  6.29512370e+02],
#        [-3.71572413e-01, -3.34565303e-01,  6.00348628e+02]])

# %%
rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))

# %%
plt.figure(figsize=(10, 10))
plt.imshow(rotated_image)

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image 
import PIL 

img = rotated_image


plt.imshow(img)

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image 
import PIL 
imgx = img[75:260,548:910,:]
 
imgx.shape
# Out:
# (185, 362, 3)

# %%
plt.figure(figsize=(10, 10))
plt.title("Original")
plt.imshow(imgx)

# %%
from PIL import Image

import numpy as np

img = Image.open("peerayut.jpg")

print(img.size)

img2 = Image.open("netitorn.jpg")

print(img2.size)
size = (405,500)
img2 = img2.resize(size,Image.ANTIALIAS)



img3 = Image.open("titikarn.jpg")

print(img3.size)

img4 = Image.open("tritep.jpg")

print(img4.size)

img5 = Image.open("siwanart.jpg")

print(img5.size)

img6 = Image.open("lotto.jpg")

print(img6.size)

size = (385,410)
img6 = img6.resize(size,Image.ANTIALIAS)

background = Image.open("skyimg.jpg")

print(background.size)

# resize the image
size = (2030,1354)
background = background.resize(size,Image.ANTIALIAS)

background.paste(img, (0,0))
background.paste(img2, (400,0))
background.paste(img3, (790,0))
background.paste(img4, (0,500))
background.paste(img5, (400,500))
background.paste(img6, (790,500))

background.save('catsky.jpg')
# Out:
# (402, 514)
# (397, 402)
# (381, 503)
# (405, 414)
# (394, 410)
# (1108, 1478)
# (626, 417)

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('catsky.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img.shape
# Out:
# (1354, 2030, 3)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(img)

# %%
img.shape
# Out:
# (1354, 2030, 3)

# %%
h,w,c = img.shape

# %%
print('h=',h,'w=',w,'c=',c)
# Out:
# h= 1354 w= 2030 c= 3

# %%
gumi = img.copy()
cv2.putText(gumi,'Peerayut',(50,150),cv2.FONT_HERSHEY_DUPLEX,2,(0,155,255),2)
cv2.putText(gumi,'55117005',(50,300),cv2.FONT_HERSHEY_SCRIPT_COMPLEX,1.5,(0,0,255),2)

cv2.putText(gumi,'Netitorn',(450,150),cv2.FONT_HERSHEY_DUPLEX,2,(0,155,255),2)
cv2.putText(gumi,'6223220005',(450,300),cv2.FONT_HERSHEY_SCRIPT_COMPLEX,1.5,(0,0,255),2)

cv2.putText(gumi,'Titikarn',(840,150),cv2.FONT_HERSHEY_DUPLEX,2,(0,155,255),2)
cv2.putText(gumi,'6223200026',(840,300),cv2.FONT_HERSHEY_SCRIPT_COMPLEX,1.5,(0,0,255),2)

cv2.putText(gumi,'Tritep',(50,650),cv2.FONT_HERSHEY_DUPLEX,2,(0,155,255),2)
cv2.putText(gumi,'6223200028',(50,800),cv2.FONT_HERSHEY_SCRIPT_COMPLEX,1.5,(0,0,255),2)

cv2.putText(gumi,'Siwanart',(450,650),cv2.FONT_HERSHEY_DUPLEX,2,(0,155,255),2)
cv2.putText(gumi,'6200000000',(450,800),cv2.FONT_HERSHEY_SCRIPT_COMPLEX,1.5,(0,0,255),2)

cv2.putText(gumi,'lottery',(840,650),cv2.FONT_HERSHEY_DUPLEX,2,(0,155,255),2)
cv2.putText(gumi,'495490',(840,800),cv2.FONT_HERSHEY_SCRIPT_COMPLEX,1.5,(0,0,255),2)
pass

# %%
plt.figure(figsize=(20, 20))
plt.imshow(gumi)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-d0d8bd772e45> in <module>()
# ----> 1 gumi.save("cat01.jpg")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'save'
